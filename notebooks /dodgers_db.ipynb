# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn
import os
import sqlite3

# %% [markdown]
# ## Data Viewing and Processing

# %%
db_path = '/Users/daniellarson/Desktop/Code/Projects/dodgers_injtrkr/data/dodgers_injury_db.sqlite'
conn = sqlite3.connect(db_path)

# %%
# Set up your DB path
base_dir = '/Users/daniellarson/Desktop/Code/Projects/dodgers_injtrkr'
db_path = os.path.join(base_dir, 'data', 'dodgers_injury_db.sqlite')

# Connect and load data
with sqlite3.connect(db_path) as conn:
    
    # Load the 'players' table
    pdf = pd.read_sql_query('SELECT * FROM players', conn)
    
    # Load the 'injuries' table
    idf = pd.read_sql_query('SELECT * FROM injuries', conn)

# %% [markdown]
# ## The Players table

# %%
pdf.columns
# Out:
# Index(['mlb_player_id', 'name', 'position', 'team', 'dob', 'bats', 'throws',
#        'weight', 'href'],
#       dtype='object')

# %%
query = 'SELECT * FROM players'
pd.read_sql_query(query, conn).head()
# Out:
#    mlb_player_id             name position                 team         dob  \
# 0         472610      Luis García     None  Los Angeles Dodgers  01/30/1987
# 1         477132  Clayton Kershaw     None  Los Angeles Dodgers  03/19/1988
# 2         489446      Kirby Yates     None  Los Angeles Dodgers  03/25/1987
# 3         500743     Miguel Rojas     None  Los Angeles Dodgers  02/24/1989
# 4         518692  Freddie Freeman     None  Los Angeles Dodgers  09/12/1989
#
#   bats throws  weight            href
# 0    R      R     240  /player/472610
# 1    L      L     225  /player/477132
# 2    L      R     205  /player/489446
# 3    R      R     188  /player/500743
# 4    L      R     220  /player/518692

# %%
# Now query it
query = 'SELECT * FROM players'
df = pd.read_sql_query(query, conn)
print(df.head(20))
# Out:
#     mlb_player_id               name position                 team  \
# 0          472610        Luis García     None  Los Angeles Dodgers
# 1          489446        Kirby Yates     None  Los Angeles Dodgers
# 2          500743       Miguel Rojas     None  Los Angeles Dodgers
# 3          518692    Freddie Freeman     None  Los Angeles Dodgers
# 4          571771  Enrique Hernández     None  Los Angeles Dodgers
# 5          571970          Max Muncy     None  Los Angeles Dodgers
# 6          605131      Austin Barnes     None  Los Angeles Dodgers
# 7          605141       Mookie Betts     None  Los Angeles Dodgers
# 8          607455      Anthony Banda     None  Los Angeles Dodgers
# 9          621035       Chris Taylor     None  Los Angeles Dodgers
# 10         623465      Evan Phillips     None  Los Angeles Dodgers
# 11         624424   Michael Conforto     None  Los Angeles Dodgers
# 12         656420    J.P. Feyereisen     None  Los Angeles Dodgers
# 13         656945       Tanner Scott     None  Los Angeles Dodgers
# 14         660271      Shohei Ohtani     None  Los Angeles Dodgers
# 15         664062      Tony Gonsolin     None  Los Angeles Dodgers
# 16         669160         Dustin May     None  Los Angeles Dodgers
# 17         669257         Will Smith     None  Los Angeles Dodgers
# 18         676263        Jack Dreyer     None  Los Angeles Dodgers
# 19         676508      Ben Casparius     None  Los Angeles Dodgers
#
#            dob bats throws  weight            href
# 0   01/30/1987    R      R     240  /player/472610
# 1   03/25/1987    L      R     205  /player/489446
# 2   02/24/1989    R      R     188  /player/500743
# 3   09/12/1989    L      R     220  /player/518692
# 4   08/24/1991    R      R     195  /player/571771
# 5   08/25/1990    L      R     215  /player/571970
# 6   12/28/1989    R      R     187  /player/605131
# 7   10/07/1992    R      R     180  /player/605141
# 8   08/10/1993    L      L     221  /player/607455
# 9   08/29/1990    R      R     196  /player/621035
# 10  09/11/1994    R      R     215  /player/623465
# 11  03/01/1993    L      R     215  /player/624424
# 12  02/07/1993    R      R     215  /player/656420
# 13  07/22/1994    R      L     235  /player/656945
# 14  07/05/1994    L      R     210  /player/660271
# 15  05/14/1994    R      R     205  /player/664062
# 16  09/06/1997    R      R     180  /player/669160
# 17  03/28/1995    R      R     195  /player/669257
# 18  02/27/1999    R      L     205  /player/676263
# 19  02/11/1999    R      R     215  /player/676508

# %% [markdown]
# ## Injuries Table

# %%
idf.columns
# Out:
# Index(['injury_id', 'mlb_player_id', 'injury_type', 'il_type', 'injury_start',
#        'injury_end', 'notes'],
#       dtype='object')

# %%
pd.read_sql_query('SELECT * FROM injuries', conn).head(10)
# Out:
#    injury_id  mlb_player_id  \
# 0          1         606192
# 1          2         669242
# 2          3         656629
# 3          4         477132
# 4          5         660271
# 5          6         595014
# 6          7         607192
# 7          8         605483
# 8          9         683618
# 9         10         669165
#
#                                          injury_type  \
# 0                                  Left groin strain
# 1                           Right ankle inflammation
# 2                         Right shoulder impingement
# 3     Recovery from left toe and left knee surgeries
# 4  Recovery from right elbow and left shoulder su...
# 5                               Right forearm sprain
# 6                        Right shoulder inflammation
# 7                         Left shoulder inflammation
# 8                           Left metatarsal fracture
# 9                   Recovery from Tommy John surgery
#
#                                        il_type injury_start  \
# 0                                        May 6         None
# 1   May 3 (10-day IL, retroactive to April 30)         None
# 2                         March 18 (60-day IL)         None
# 3                         March 18 (60-day IL)         None
# 4                                                      None
# 5                         April 19 (60-day IL)         None
# 6                         April 28 (15-day IL)         None
# 7  April 6 (15-day IL, retroactive to April 3)         None
# 8                         March 18 (60-day IL)         None
# 9                         March 18 (60-day IL)         None
#
#                       injury_end  \
# 0                            TBD
# 1             Possibly May 13-15
# 2                            May
# 3  Mid- to late May, at earliest
# 4               TBD as a pitcher
# 5               June at earliest
# 6                            TBD
# 7                            May
# 8           Late May at earliest
# 9          Late 2025 at earliest
#
#                                                notes
# 0  An MRI revealed a Grade 1 adductor strain; man...
# 1  Resumed running on May 6, per manager Dave Rob...
# 2  Has resumed facing hitters and is expected to ...
# 3  Completed five innings on 66 pitches for Tripl...
# 4  Threw his second bullpen session since going o...
# 5  Imaging revealed a low-grade sprain; has not r...
# 6  Exited his April 27 start before throwing a pi...
# 7  Shut down from throwing after feeling unwell a...
# 8  Sustained a non-baseball injury and was not re...
# 9  Underwent Tommy John surgery last July; has re...

# %% [markdown]
# ## New Name and Injuries dataset.

# %%
# Open a new DB connection
db_path = '/Users/daniellarson/Desktop/Code/Projects/dodgers_injtrkr/data/dodgers_injury_db.sqlite'
conn = sqlite3.connect(db_path)

# Your SQL query
query = '''
SELECT players.name, injuries.*
FROM players
JOIN injuries ON players.mlb_player_id = injuries.mlb_player_id
'''

# Run query while the DB is open
names_injuries = pd.read_sql_query(query, conn)

# Close the connection AFTER reading

# %%
# See the column names
print(names_injuries.columns)
# Out:
# Index(['name', 'injury_id', 'mlb_player_id', 'injury_type', 'il_type',
#        'injury_start', 'injury_end', 'notes'],
#       dtype='object')

# %%
# See the first few rows
names_injuries.head()
# Out:
#                 name  injury_id  mlb_player_id  \
# 0  Teoscar Hernández          1         606192
# 1        Tommy Edman          2         669242
# 2     Michael Kopech          3         656629
# 3    Clayton Kershaw          4         477132
# 4      Shohei Ohtani          5         660271
#
#                                          injury_type  \
# 0                                  Left groin strain
# 1                           Right ankle inflammation
# 2                         Right shoulder impingement
# 3     Recovery from left toe and left knee surgeries
# 4  Recovery from right elbow and left shoulder su...
#
#                                       il_type injury_start  \
# 0                                       May 6         None
# 1  May 3 (10-day IL, retroactive to April 30)         None
# 2                        March 18 (60-day IL)         None
# 3                        March 18 (60-day IL)         None
# 4                                                     None
#
#                       injury_end  \
# 0                            TBD
# 1             Possibly May 13-15
# 2                            May
# 3  Mid- to late May, at earliest
# 4               TBD as a pitcher
#
#                                                notes
# 0  An MRI revealed a Grade 1 adductor strain; man...
# 1  Resumed running on May 6, per manager Dave Rob...
# 2  Has resumed facing hitters and is expected to ...
# 3  Completed five innings on 66 pitches for Tripl...
# 4  Threw his second bullpen session since going o...

# %%
# Filter only certain columns
names_injuries[['name', 'injury_type', 'injury_start']].head(10)
# Out:
#                 name                                        injury_type  \
# 0  Teoscar Hernández                                  Left groin strain
# 1        Tommy Edman                           Right ankle inflammation
# 2     Michael Kopech                         Right shoulder impingement
# 3    Clayton Kershaw     Recovery from left toe and left knee surgeries
# 4      Shohei Ohtani  Recovery from right elbow and left shoulder su...
# 5      Blake Treinen                               Right forearm sprain
# 6      Tyler Glasnow                        Right shoulder inflammation
# 7        Blake Snell                         Left shoulder inflammation
# 8  Edgardo Henriquez                           Left metatarsal fracture
# 9          Kyle Hurt                   Recovery from Tommy John surgery
#
#   injury_start
# 0         None
# 1         None
# 2         None
# 3         None
# 4         None
# 5         None
# 6         None
# 7         None
# 8         None
# 9         None

# %%
# Filter rows (example: only active injuries)
active_injuries = names_injuries[names_injuries['injury_end'].isnull()]

active_injuries.head()
# Out:
#                  name  injury_id  mlb_player_id  \
# 28      Emmet Sheehan         29         686218
# 30   Brusdar Graterol         31         660813
# 31         River Ryan         32         689981
# 32        Gavin Stone         33         694813
# 33  Teoscar Hernández         34         606192
#
#                          injury_type il_type injury_start injury_end notes
# 28  Recovery from Tommy John surgery    None         None       None  None
# 30                              None    None         None       None  None
# 31                              None    None         None       None  None
# 32                              None    None         None       None  None
# 33                              None    None         None       None  None

# %%
# All active injuries

all_active_injuries = active_injuries[:] 

all_active_injuries
# Out:
#                  name  injury_id  mlb_player_id  \
# 28      Emmet Sheehan         29         686218
# 30   Brusdar Graterol         31         660813
# 31         River Ryan         32         689981
# 32        Gavin Stone         33         694813
# 33  Teoscar Hernández         34         606192
# 34        Tommy Edman         35         669242
# 35     Michael Kopech         36         656629
#
#                          injury_type il_type injury_start injury_end notes
# 28  Recovery from Tommy John surgery    None         None       None  None
# 30                              None    None         None       None  None
# 31                              None    None         None       None  None
# 32                              None    None         None       None  None
# 33                              None    None         None       None  None
# 34                              None    None         None       None  None
# 35                              None    None         None       None  None

# %% [markdown]
# ## Close Database

# %%
conn.close()
