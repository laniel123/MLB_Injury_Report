# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn
import os
import sqlite3

# %% [markdown]
# ## Data Viewing and Processing

# %%
# Set the path to your project directory (adjust if needed)
base_dir = '/Users/daniellarson/Desktop/Code/Projects/dodgers_injtrkr'
db_path = os.path.join(base_dir, 'data', 'dodgers_injury_db.sqlite')

# Connect to the SQLite database
conn = sqlite3.connect(db_path)
cursor = conn.cursor()

# ✅ Now you can run your queries!
cursor.execute('SELECT name FROM sqlite_master WHERE type="table";')
print(cursor.fetchall())

conn.close()
# Out:
# [('players',), ('sqlite_sequence',), ('injuries',), ('games',), ('player_game_stats',), ('risk_scores',)]

# %%
# Set up your DB path
base_dir = '/Users/daniellarson/Desktop/Code/Projects/dodgers_injtrkr'
db_path = os.path.join(base_dir, 'data', 'dodgers_injury_db.sqlite')

# Connect and load data
with sqlite3.connect(db_path) as conn:
    
    # Load the 'players' table
    pdf = pd.read_sql_query('SELECT * FROM players', conn)
    
    # Load the 'injuries' table
    idf = pd.read_sql_query('SELECT * FROM injuries', conn).head(5)

# %%
pdf.columns
# Out:
# Index(['player_id', 'name', 'position', 'team', 'dob', 'bats', 'throws',
#        'weight'],
#       dtype='object')

# %%
idf.columns
# Out:
# Index(['injury_id', 'player_id', 'injury_type', 'il_type', 'injury_start',
#        'injury_end', 'notes'],
#       dtype='object')

# %%
#Players table info
pd.read_sql_query('SELECT * FROM players', conn)

#pd.read_sql_query('SELECT * FROM injuries', conn).head(5)
# Out:
#     player_id                           name position                 team  \
# 0           1              Teoscar Hernández     None                 None
# 1           2                    Tommy Edman     None                 None
# 2           3                 Michael Kopech     None                 None
# 3           4                Clayton Kershaw     None                 None
# 4           5                  Shohei Ohtani     None                 None
# 5           6                  Blake Treinen     None                 None
# 6           7                  Tyler Glasnow     None                 None
# 7           8                    Blake Snell     None                 None
# 8           9              Edgardo Henriquez     None                 None
# 9          10                      Kyle Hurt     None                 None
# 10         11                  Emmet Sheehan     None                 None
# 11         12                  Michael Grove     None                 None
# 12         13               Brusdar Graterol     None                 None
# 13         14                     River Ryan     None                 None
# 14         15                    Gavin Stone     None                 None
# 15         16       More Dodgers injury news     None                 None
# 16         19                  Tony Gonsolin     None                 None
# 17         20  Complete Dodgers transactions     None                 None
# 18         21                 Privacy Policy     None                 None
# 19         43                  Anthony Banda     None  Los Angeles Dodgers
# 20         44                  Ben Casparius     None  Los Angeles Dodgers
# 21         45                    Jack Dreyer     None  Los Angeles Dodgers
# 22         46                J.P. Feyereisen     None  Los Angeles Dodgers
# 23         47                    Luis García     None  Los Angeles Dodgers
# 24         49                     Dustin May     None  Los Angeles Dodgers
# 25         50                  Evan Phillips     None  Los Angeles Dodgers
# 26         51                    Roki Sasaki     None  Los Angeles Dodgers
# 27         52                   Tanner Scott     None  Los Angeles Dodgers
# 28         53                     Alex Vesia     None  Los Angeles Dodgers
# 29         54             Yoshinobu Yamamoto     None  Los Angeles Dodgers
# 30         55                    Kirby Yates     None  Los Angeles Dodgers
# 31         57                  Austin Barnes     None  Los Angeles Dodgers
# 32         58                     Will Smith     None  Los Angeles Dodgers
# 33         59                   Mookie Betts     None  Los Angeles Dodgers
# 34         60                Freddie Freeman     None  Los Angeles Dodgers
# 35         61              Enrique Hernández     None  Los Angeles Dodgers
# 36         62                   Hyeseong Kim     None  Los Angeles Dodgers
# 37         63                      Max Muncy     None  Los Angeles Dodgers
# 38         64                   Miguel Rojas     None  Los Angeles Dodgers
# 39         65               Michael Conforto     None  Los Angeles Dodgers
# 40         66                   James Outman     None  Los Angeles Dodgers
# 41         67                     Andy Pages     None  Los Angeles Dodgers
# 42         68                   Chris Taylor     None  Los Angeles Dodgers
# 43         97                     Noah Davis     None  Los Angeles Dodgers
# 44        100                    Nick Frasso     None  Los Angeles Dodgers
# 45        109                   Landon Knack     None  Los Angeles Dodgers
# 46        111                    Ryan Loutos     None  Los Angeles Dodgers
# 47        113                   Bobby Miller     None  Los Angeles Dodgers
# 48        117                     Matt Sauer     None  Los Angeles Dodgers
# 49        124               Justin Wrobleski     None  Los Angeles Dodgers
# 50        132                Hunter Feduccia     None  Los Angeles Dodgers
# 51        142                   Esteury Ruiz     None  Los Angeles Dodgers
#
#            dob  bats throws  weight
# 0         None  None   None     NaN
# 1         None  None   None     NaN
# 2         None  None   None     NaN
# 3         None  None   None     NaN
# 4         None  None   None     NaN
# 5         None  None   None     NaN
# 6         None  None   None     NaN
# 7         None  None   None     NaN
# 8         None  None   None     NaN
# 9         None  None   None     NaN
# 10        None  None   None     NaN
# 11        None  None   None     NaN
# 12        None  None   None     NaN
# 13        None  None   None     NaN
# 14        None  None   None     NaN
# 15        None  None   None     NaN
# 16        None  None   None     NaN
# 17        None  None   None     NaN
# 18        None  None   None     NaN
# 19  08/10/1993     L      L   221.0
# 20  02/11/1999     R      R   215.0
# 21  02/27/1999     R      L   205.0
# 22  02/07/1993     R      R   215.0
# 23  01/30/1987     R      R   240.0
# 24  09/06/1997     R      R   180.0
# 25  09/11/1994     R      R   215.0
# 26  11/03/2001     R      R   187.0
# 27  07/22/1994     R      L   235.0
# 28  04/11/1996     L      L   209.0
# 29  08/17/1998     R      R   176.0
# 30  03/25/1987     L      R   205.0
# 31  12/28/1989     R      R   187.0
# 32  03/28/1995     R      R   195.0
# 33  10/07/1992     R      R   180.0
# 34  09/12/1989     L      R   220.0
# 35  08/24/1991     R      R   195.0
# 36  01/27/1999     L      R   175.0
# 37  08/25/1990     L      R   215.0
# 38  02/24/1989     R      R   188.0
# 39  03/01/1993     L      R   215.0
# 40  05/14/1997     L      R   215.0
# 41  12/08/2000     R      R   212.0
# 42  08/29/1990     R      R   196.0
# 43  04/22/1997     R      R   195.0
# 44  10/18/1998     R      R   200.0
# 45  07/15/1997     L      R   220.0
# 46  01/29/1999     R      R   240.0
# 47  04/05/1999     L      R   220.0
# 48  01/21/1999     R      R   230.0
# 49  07/14/2000     L      L   194.0
# 50  06/05/1997     L      R   215.0
# 51  02/15/1999     R      R   169.0

# %%
# Open a new DB connection
db_path = '/Users/daniellarson/Desktop/Code/Projects/dodgers_injtrkr/data/dodgers_injury_db.sqlite'
conn = sqlite3.connect(db_path)

# Your SQL query
query = '''
SELECT players.name, injuries.*
FROM players
JOIN injuries ON players.player_id = injuries.player_id
'''

# Run query while the DB is open
names_injuries = pd.read_sql_query(query, conn)

# View the first 5 rows
names_injuries.head()

# Close the connection AFTER reading
conn.close()
# Out:
#                 name  injury_id  player_id  \
# 0  Teoscar Hernández          1          1
# 1        Tommy Edman          2          2
# 2     Michael Kopech          3          3
# 3    Clayton Kershaw          4          4
# 4      Shohei Ohtani          5          5
#
#                                          injury_type  \
# 0                           Left hamstring tightness
# 1                           Right ankle inflammation
# 2                         Right shoulder impingement
# 3     Recovery from left toe and left knee surgeries
# 4  Recovery from right elbow and left shoulder su...
#
#                                       il_type injury_start  \
# 0                                                     None
# 1  May 3 (10-day IL, retroactive to April 30)         None
# 2                        March 18 (60-day IL)         None
# 3                        March 18 (60-day IL)         None
# 4                                                     None
#
#                       injury_end  \
# 0                            TBD
# 1                            TBD
# 2                            May
# 3  Mid- to late May, at earliest
# 4               TBD as a pitcher
#
#                                                notes
# 0  Removed before the bottom of the fourth inning...
# 1  Tweaked his right ankle on April 29 and was pl...
# 2  Has resumed facing hitters and is expected to ...
# 3  Completed five innings on 66 pitches for Tripl...
# 4  Threw his second bullpen session since going o...

# %%
pd.sql_query('SELECT * FROM players', conn)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 pd.sql_query('SELECT * FROM players', conn)
#
# AttributeError: module 'pandas' has no attribute 'sql_query'

# %%
# Injuries table info
idf.head(10)
# Out:
#    injury_id  player_id                                        injury_type  \
# 0          1          1                           Left hamstring tightness
# 1          2          2                           Right ankle inflammation
# 2          3          3                         Right shoulder impingement
# 3          4          4     Recovery from left toe and left knee surgeries
# 4          5          5  Recovery from right elbow and left shoulder su...
# 5          6          6                               Right forearm sprain
# 6          7          7                        Right shoulder inflammation
# 7          8          8                         Left shoulder inflammation
# 8          9          9                           Left metatarsal fracture
# 9         10         10                   Recovery from Tommy John surgery
#
#                                        il_type injury_start  \
# 0                                                      None
# 1   May 3 (10-day IL, retroactive to April 30)         None
# 2                         March 18 (60-day IL)         None
# 3                         March 18 (60-day IL)         None
# 4                                                      None
# 5                         April 19 (60-day IL)         None
# 6                         April 28 (15-day IL)         None
# 7  April 6 (15-day IL, retroactive to April 3)         None
# 8                         March 18 (60-day IL)         None
# 9                         March 18 (60-day IL)         None
#
#                       injury_end  \
# 0                            TBD
# 1                            TBD
# 2                            May
# 3  Mid- to late May, at earliest
# 4               TBD as a pitcher
# 5               June at earliest
# 6                            TBD
# 7                            May
# 8           Late May at earliest
# 9          Late 2025 at earliest
#
#                                                notes
# 0  Removed before the bottom of the fourth inning...
# 1  Tweaked his right ankle on April 29 and was pl...
# 2  Has resumed facing hitters and is expected to ...
# 3  Completed five innings on 66 pitches for Tripl...
# 4  Threw his second bullpen session since going o...
# 5  Imaging revealed a low-grade sprain; has not r...
# 6  Exited his April 27 start before throwing a pi...
# 7  Shut down from throwing after feeling unwell a...
# 8  Sustained a non-baseball injury and was not re...
# 9  Underwent Tommy John surgery last July; has re...

# %%
# Now you can use df.head(), df.describe(), etc.

print("=== Players Table Head ===")
print(pdf.head())

print("\n=== Injuries Table Head ===")
print(idf.head())

# More exploration examples:
print("\nPlayers table info:")
print(pdf.info())

print("\nInjuries summary stats:")
print(idf.describe())
# Out:
# === Players Table Head ===
#    player_id               name position  team   dob  bats throws  weight
# 0          1  Teoscar Hernández     None  None  None  None   None     NaN
# 1          2        Tommy Edman     None  None  None  None   None     NaN
# 2          3     Michael Kopech     None  None  None  None   None     NaN
# 3          4    Clayton Kershaw     None  None  None  None   None     NaN
# 4          5      Shohei Ohtani     None  None  None  None   None     NaN
#
# === Injuries Table Head ===
#    injury_id  player_id                                        injury_type  \
# 0          1          1                           Left hamstring tightness
# 1          2          2                           Right ankle inflammation
# 2          3          3                         Right shoulder impingement
# 3          4          4     Recovery from left toe and left knee surgeries
# 4          5          5  Recovery from right elbow and left shoulder su...
#
#                                       il_type injury_start  \
# 0                                                     None
# 1  May 3 (10-day IL, retroactive to April 30)         None
# 2                        March 18 (60-day IL)         None
# 3                        March 18 (60-day IL)         None
# 4                                                     None
#
#                       injury_end  \
# 0                            TBD
# 1                            TBD
# 2                            May
# 3  Mid- to late May, at earliest
# 4               TBD as a pitcher
#
#                                                notes
# 0  Removed before the bottom of the fourth inning...
# 1  Tweaked his right ankle on April 29 and was pl...
# 2  Has resumed facing hitters and is expected to ...
# 3  Completed five innings on 66 pitches for Tripl...
# 4  Threw his second bullpen session since going o...
#
# Players table info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   player_id  43 non-null     int64
#  1   name       43 non-null     object
#  2   position   0 non-null      object
#  3   team       24 non-null     object
#  4   dob        24 non-null     object
#  5   bats       24 non-null     object
#  6   throws     24 non-null     object
#  7   weight     24 non-null     float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 2.8+ KB
# None
#
# Injuries summary stats:
#        injury_id  player_id
# count  42.000000  42.000000
# mean   21.500000   9.142857
# std    12.267844   6.150833
# min     1.000000   1.000000
# 25%    11.250000   3.250000
# 50%    21.500000   8.500000
# 75%    31.750000  13.750000
# max    42.000000  21.000000

# %%
df = pd.read_sql_query('SELECT * FROM injuries', conn)
print(df)
# Out:
#     injury_id  player_id                                        injury_type  \
# 0           1          1                           Left hamstring tightness
# 1           2          2                           Right ankle inflammation
# 2           3          3                         Right shoulder impingement
# 3           4          4     Recovery from left toe and left knee surgeries
# 4           5          5  Recovery from right elbow and left shoulder su...
# 5           6          6                               Right forearm sprain
# 6           7          7                        Right shoulder inflammation
# 7           8          8                         Left shoulder inflammation
# 8           9          9                           Left metatarsal fracture
# 9          10         10                   Recovery from Tommy John surgery
# 10         11         11                   Recovery from Tommy John surgery
# 11         12         12                      Right shoulder labrum surgery
# 12         13         13             : Recovery from right shoulder surgery
# 13         14         14                 : Recovery from Tommy John surgery
# 14         15         15             : Recovery from right shoulder surgery
# 15         16         16
# 16         17          2
# 17         18          3
# 18         19         19
# 19         20         20
# 20         21         21
#
#                                         il_type injury_start  \
# 0                                                       None
# 1    May 3 (10-day IL, retroactive to April 30)         None
# 2                          March 18 (60-day IL)         None
# 3                          March 18 (60-day IL)         None
# 4                                                       None
# 5                          April 19 (60-day IL)         None
# 6                          April 28 (15-day IL)         None
# 7   April 6 (15-day IL, retroactive to April 3)         None
# 8                          March 18 (60-day IL)         None
# 9                          March 18 (60-day IL)         None
# 10                         March 18 (60-day IL)         None
# 11                         March 18 (60-day IL)         None
# 12                         March 18 (60-day IL)         None
# 13                          Feb. 13 (60-day IL)         None
# 14                          Feb. 11 (60-day IL)         None
# 15                                                      None
# 16                                                      None
# 17                                                      None
# 18                                                      None
# 19                                                      None
# 20                                                      None
#
#                               injury_end  \
# 0                                    TBD
# 1                                    TBD
# 2                                    May
# 3          Mid- to late May, at earliest
# 4                       TBD as a pitcher
# 5                       June at earliest
# 6                                    TBD
# 7                                    May
# 8                   Late May at earliest
# 9                  Late 2025 at earliest
# 10  : Possibly before the All-Star break
# 11                                  2026
# 12                 : Second half of 2025
# 13               : Late 2025 at earliest
# 14                                : 2026
# 15
# 16
# 17
# 18
# 19
# 20
#
#                                                 notes
# 0   Removed before the bottom of the fourth inning...
# 1   Tweaked his right ankle on April 29 and was pl...
# 2   Has resumed facing hitters and is expected to ...
# 3   Completed five innings on 66 pitches for Tripl...
# 4   Threw his second bullpen session since going o...
# 5   Imaging revealed a low-grade sprain; has not r...
# 6   Exited his April 27 start before throwing a pi...
# 7   Shut down from throwing after feeling unwell a...
# 8   Sustained a non-baseball injury and was not re...
# 9   Underwent Tommy John surgery last July; has re...
# 10  : Underwent Tommy John surgery in May 2024; ha...
# 11  Underwent a right labrum procedure in March; e...
# 12  : Underwent right shoulder labrum surgery last...
# 13  : Underwent Tommy John surgery last August; ha...
# 14  : Underwent right shoulder surgery last Oct. 9...
# 15
# 16
# 17
# 18
# 19
# 20
